# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
g=df.groupby('Sex')

for name,group in g:
    print(name)
    print(group)
# Out:
# female
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex        Age  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.000000
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.000000
# ..                                                 ...     ...        ...
# ...

# %%
df['Age'].describe()
# Out:
# count    891.000000
# mean      29.699118
# std       13.002015
# min        0.420000
# 25%       22.000000
# 50%       29.699118
# 75%       35.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
g=df['Age'].axes
# g.plot(kind='hist',bins=10)

# %%
df[['Age','Fare']][df['Fare']>100].dropna(how='any')
# Out:
#            Age      Fare
# 27   19.000000  263.0000
# 31   29.699118  146.5208
# 88   23.000000  263.0000
# 118  24.000000  247.5208
# 195  58.000000  146.5208
# 215  31.000000  113.2750
# 258  35.000000  512.3292
# 268  58.000000  153.4625
# 269  35.000000  135.6333
# 297   2.000000  151.5500
# 299  50.000000  247.5208
# 305   0.920000  151.5500
# 306  29.699118  110.8833
# 307  17.000000  108.9000
# 311  18.000000  262.3750
# 318  31.000000  164.8667
# 319  40.000000  134.5000
# 325  36.000000  135.6333
# 332  38.000000  153.4625
# 334  29.699118  133.6500
# 337  41.000000  134.5000
# 341  24.000000  263.0000
# 373  22.000000  135.6333
# 377  27.000000  211.5000
# 380  42.000000  227.5250
# 390  36.000000  120.0000
# 393  23.000000  113.2750
# 435  14.000000  120.0000
# 438  64.000000  263.0000
# 498  25.000000  151.5500
# 505  18.000000  108.9000
# 527  29.699118  221.7792
# 537  30.000000  106.4250
# 544  50.000000  106.4250
# 550  17.000000  110.8833
# 557  29.699118  227.5250
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
new=df.fillna({
    "Cabin":"Unknown Cabin",
    "Embarked":"Na",
    "Age":df['Age'].mean()
})
new.to_csv('titanic.csv',index=False)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   13.002015    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   29.699118    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
def get_first_name(name):
    return name.split(',')[1]

def get_last_name(name):
    return name.split(',')[0]
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df['First Name'] = df['Name'].apply(get_first_name)
df['Last Name'] = df['Name'].apply(get_last_name)

columns = list(df.columns)


columns.remove('First Name')
columns.remove('Last Name')
columns.remove('Name')

columns.insert(3, 'First Name')
columns.insert(4, 'Last Name')

df = df[columns]

df.to_csv('titanic_2.csv',index=False)

# %%
df=pd.read_csv('titanic.csv')

import seaborn as sns
import matplotlib.pyplot as plt

print(df.columns)

sns.histplot(df['Age'], bins=10)
plt.show()

sns.barplot(x='Sex', y='Survived', data=df)
plt.show()

numeric_df = df.select_dtypes(include='number')

df_corr = numeric_df.drop(columns='PassengerId').corr()

sns.heatmap(df_corr, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
